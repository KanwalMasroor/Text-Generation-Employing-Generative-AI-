# %%
## Installing required libraries
# !pip install langchain-huggingface

## For API Calls
# !pip install huggingface_hub
# !pip install transformers
# !pip install accelerate
# !pip install  bitsandbytes
# !pip install langchain
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.4/50.4 kB 902.9 kB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 404.4/404.4 kB 24.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 255.2/255.2 kB 13.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 295.8/295.8 kB 13.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.4/76.4 kB 3.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.0/78.0 kB 6.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 141.9/141.9 kB 8.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 2.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 3.7 MB/s eta 0:00:00
# ...
#   Attempting uninstall: tenacity
#     Found existing installation: tenacity 9.0.0
#     Uninstalling tenacity-9.0.0:
#       Successfully uninstalled tenacity-9.0.0
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 122.4/122.4 MB 7.6 MB/s eta 0:00:00
# ...

# %%
## Access Environment secret keys
from google.colab import userdata
seckey=userdata.get("HF_TOKEN")
print(seckey)

# %%
#Method 1:
from langchain_huggingface import HuggingFaceEndpoint

# %%
import os
os.environ["HF_TOKEN"]=seckey

# %%
repo_id="meta-llama/Llama-3.2-3B-Instruct"
llm=HuggingFaceEndpoint(repo_id=repo_id,max_length=128,temperature=0.7,token=seckey)
# Out:
# WARNING:langchain_huggingface.llms.huggingface_endpoint:WARNING! max_length is not default parameter.
#                     max_length was transferred to model_kwargs.
#                     Please make sure that max_length is what you intended.
# WARNING:langchain_huggingface.llms.huggingface_endpoint:WARNING! token is not default parameter.
#                     token was transferred to model_kwargs.
#                     Please make sure that token is what you intended.
# The token has not been saved to the git credentials helper. Pass `add_to_git_credential=True` in this function directly or `--add-to-git-credential` if using via `huggingface-cli` if you want to set the git credential as well.
# Token is valid (permission: read).
# Your token has been saved to /root/.cache/huggingface/token
# Login successful

# %%
llm.invoke("What is Machine Learning")
# Out:
# '? Machine learning is a subset of artificial intelligence (AI) that provides systems the ability to automatically learn and improve from experience without being explicitly programmed.\nIn machine learning, the system learns from data, identifies patterns, and makes predictions or decisions based on that data. The goal is to enable computers to perform tasks that would typically require human intelligence, such as recognizing images, speech, or text, or making decisions based on complex data sets.\nThere are several types of machine learning, including:\n1. **Supervised Learning**: The system is trained on labeled data, where the correct output is already known. The system learns to map inputs to outputs based on the labeled data.\n2. **Unsupervised Learning**: The system is trained on unlabeled data, and it must find patterns or structure in the data on its own.\n3. **Reinforcement Learning**: The system learns through trial and error by interacting with an environment and receivin
# ...

# %%
llm.invoke("What is Machine Learning?")
# Out:
# " Machine learning is a subset of artificial intelligence that involves training algorithms to make predictions or decisions based on data. It's a way of teaching computers to learn from experience and improve their performance over time.\nMachine learning algorithms use various techniques such as supervised learning, unsupervised learning, and reinforcement learning to analyze data and make predictions or decisions. Supervised learning involves training algorithms on labeled data, where the correct output is already known. Unsupervised learning involves training algorithms on unlabeled data, where the algorithm must identify patterns or relationships on its own. Reinforcement learning involves training algorithms to make decisions based on rewards or penalties.\nMachine learning has many applications, including:\nImage and speech recognition\nNatural language processing\nPredictive maintenance\nRecommendation systems\nChatbots\nSelf-driving cars\nPersonalized medicine\nHere are some
# ...

# %%
llm.invoke("What is Capital of UAE?")
# Out:
# " \nThe capital of the United Arab Emirates (UAE) is Abu Dhabi. It is the third-largest city in the UAE and is home to the country's presidential palace and the grand mosque. Abu Dhabi has a rich history and has been an important center for trade and commerce in the region for centuries. Today, it is a thriving metropolis with a diverse population and a strong economy.\n\nHere are some interesting facts about Abu Dhabi:\n\n1. **Abu Dhabi is the 7th safest city in the world**: According to the Global Peace Index, Abu Dhabi is one of the safest cities in the world.\n2. **Home to the Sheikh Zayed Mosque**: The Sheikh Zayed Mosque is one of the largest mosques in the world and is a major tourist attraction in Abu Dhabi.\n3. **Abu Dhabi has a strong economy**: The city is a major hub for business and finance in the Middle East, with a strong focus on oil and gas, as well as tourism and real estate.\n4. **Abu Dhabi is a popular destination for tourism**: The city has a rich history and cul
# ...

# %%
from langchain import PromptTemplate, LLMChain

question="What is the capital of UAE?"
template = """Question: {question}
Answer: Let's think step by step."""
prompt = PromptTemplate(template=template, input_variables=["question"])
print(prompt)
# Out:
# input_variables=['question'] input_types={} partial_variables={} template="Question: {question}\nAnswer: Let's think step by step."

# %%
llm_chain = LLMChain(prompt=prompt, llm=llm)
print(llm_chain.invoke(question))
# Out:
# {'question': 'What is the capital of UAE?', 'text': " The UAE (United Arab Emirates) is a country located in the Middle East. It's known for its rich oil reserves, modern architecture, and diverse culture. To determine its capital, let's consider some key facts:\n1. The UAE is a federation of seven emirates: Abu Dhabi, Dubai, Sharjah, Ajman, Umm Al Quwain, Ras Al Khaimah, and Fujairah.\n2. Each emirate has its own government and ruler, known as an emir.\n3. The capital of a country is typically the seat of the national government and the location of the country's main institutions.\n\nGiven these points, we need to identify which emirate serves as the capital of the UAE. The most prominent emirate in terms of economy, tourism, and global influence is Dubai. However, the actual capital of the UAE is Abu Dhabi, which hosts the country's presidential palace, the federal government ministries, and other national institutions.\n\nThe best answer is Abu Dhabi."}

# %%
#Method 2:
from langchain_huggingface import HuggingFacePipeline
from transformers import AutoModelForCausalLM, AutoTokenizer, pipeline

# %%
model_id="gpt2-medium"
model=AutoModelForCausalLM.from_pretrained(model_id)
tokenizer=AutoTokenizer.from_pretrained(model_id)
# Out:
# config.json:   0%|          | 0.00/718 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.52G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(

# %%
pipe=pipeline("text-generation",model=model,tokenizer=tokenizer,max_new_tokens=50)
hf=HuggingFacePipeline(pipeline=pipe)
# Out:
# Hardware accelerator e.g. GPU is available in the environment, but no `device` argument is passed to the `Pipeline` object. Model will be on CPU.

# %%
hf
# Out:
# HuggingFacePipeline(pipeline=<transformers.pipelines.text_generation.TextGenerationPipeline object at 0x798c2b66df00>)

# %%
hf.invoke("What is capital of UAE")
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# "What is capital of UAE?\n\nYou are sitting at your desk and think how stupid are you? But it doesn't matter what you are thinking because it is your investment! You invest money to create a future. You will create a future in your own image. It"

# %%
## Use HuggingfacePipelines With Gpu
gpu_llm = HuggingFacePipeline.from_model_id(
    model_id="gpt2-medium",
    task="text-generation",
    device=0,  # replace with device_map="auto" to use the accelerate library.
    pipeline_kwargs={"max_new_tokens": 100},
)
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(

# %%
from langchain_core.prompts import PromptTemplate

template = """Question: {question}

Answer: Let's think step by step."""
prompt = PromptTemplate.from_template(template)

# %%
chain=prompt|gpu_llm

# %%
question="What is artificial intelligence?"
chain.invoke({"question":question})
# Out:
# "Question: What is artificial intelligence?\n\nAnswer: Let's think step by step. Artificial intelligence uses computer programs for specific tasks, and machines for similar-task-oriented tasks. They compete for jobs in the marketplace and decide whether or not to accept certain jobs. For example, if you have a machine that helps you drive cars, it could run the software that drives that car and pick up the data generated by that car. That data will go to the car manufacturer, where it helps them design better products. In contrast, what would seem like a relatively minor task for a machine"
